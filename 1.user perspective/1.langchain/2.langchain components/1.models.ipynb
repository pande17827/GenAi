# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Langchain provide standard interface for all llm like Chatgpt,Anthropic,LLma etc

# %% [markdown]
# ![image.png](attachment:image.png)
